# %%
from tensorflow.keras.preprocessing.text import one_hot

# %% [markdown]
# #### Sentences

# %%
sent=['the glass of mik',
      'the glass of juice',
      'the cup of tea',
      'I am a good boy',
      'I am a good developer',
      'understand the meaning of words',
      'your videos are good']

# %%
sent
# Out:
# ['the glass of mik',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %% [markdown]
# ##### Define the vocabulary size

# %% [markdown]
# ###### One-hot representation

# %%
voc_size=10000

# %%
one_hot_repr=[one_hot(words,voc_size) for words in sent]
one_hot_repr
# Out:
# [[3924, 6908, 6924, 5342],
#  [3924, 6908, 6924, 4582],
#  [3924, 6070, 6924, 733],
#  [8634, 5933, 4067, 6487, 5687],
#  [8634, 5933, 4067, 6487, 4087],
#  [6809, 3924, 930, 6924, 8318],
#  [9533, 2108, 7585, 6487]]

# %% [markdown]
# ###### Word Embedding Representation

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length=8
embedded_docs=pad_sequences(one_hot_repr,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 3924 6908 6924 5342]
#  [   0    0    0    0 3924 6908 6924 4582]
#  [   0    0    0    0 3924 6070 6924  733]
#  [   0    0    0 8634 5933 4067 6487 5687]
#  [   0    0    0 8634 5933 4067 6487 4087]
#  [   0    0    0 6809 3924  930 6924 8318]
#  [   0    0    0    0 9533 2108 7585 6487]]

# %% [markdown]
# #### Feature Representation

# %%
dim=10

# %%
model = Sequential()
model.add(Embedding(input_dim=voc_size,output_dim=dim,input_shape=(sent_length,)))
model.build()

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_4 (Embedding)         │ (None, 8, 10)          │       100,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 100,000 (390.62 KB)
#  Trainable params: 100,000 (390.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# array([[[ 0.0285976 ,  0.04631207, -0.00358213, -0.0376596 ,
#          -0.04114353,  0.03049013,  0.02673307,  0.03592468,
#           0.00895162,  0.04234786],
#         [ 0.0285976 ,  0.04631207, -0.00358213, -0.0376596 ,
#          -0.04114353,  0.03049013,  0.02673307,  0.03592468,
#           0.00895162,  0.04234786],
#         [ 0.0285976 ,  0.04631207, -0.00358213, -0.0376596 ,
#          -0.04114353,  0.03049013,  0.02673307,  0.03592468,
#           0.00895162,  0.04234786],
#         [ 0.0285976 ,  0.04631207, -0.00358213, -0.0376596 ,
#          -0.04114353,  0.03049013,  0.02673307,  0.03592468,
#           0.00895162,  0.04234786],
#         [-0.02006943, -0.00349691,  0.00442221, -0.03003154,
#           0.02992251, -0.03030045, -0.03131988, -0.0471345 ,
#           0.00884849, -0.04877849],
#         [ 0.01752121,  0.02925109, -0.02762285,  0.03814505,
#           0.03597647, -0.0364292 ,  0.04771555,  0.00339765,
#           0.02951619,  0.00691339],
#         [-0.02897176, -0.0300827 , -0.04947052,  0.03212515,
#           0.00135672, -0.0203939 , -0.00619284,  0.02111692,
#           0.03216496, -0.03797439],
#         [-0.04304372,  0.0285144 ,  0.03843181, -0.02894433,
#           0.00349753, -0.01045462, -0.0003374 ,  0.04177096,
#          -0.00351216, -0.02375209]],
#
#        [[ 0.0285976 ,  0.04631207, -0.00358213, -0.0376596 ,
#          -0.04114353,  0.03049013,  0.02673307,  0.03592468,
#           0.00895162,  0.04234786],
#         [ 0.0285976 ,  0.04631207, -0.00358213, -0.0376596 ,
#          -0.04114353,  0.03049013,  0.02673307,  0.03592468,
#           0.00895162,  0.04234786],
#         [ 0.0285976 ,  0.04631207, -0.00358213, -0.0376596 ,
#          -0.04114353,  0.03049013,  0.02673307,  0.03592468,
#           0.00895162,  0.04234786],
#         [ 0.0285976 ,  0.04631207, -0.00358213, -0.0376596 ,
#          -0.04114353,  0.03049013,  0.02673307,  0.03592468,
#           0.00895162,  0.04234786],
#         [-0.02006943, -0.00349691,  0.00442221, -0.03003154,
#           0.02992251, -0.03030045, -0.03131988, -0.0471345 ,
#           0.00884849, -0.04877849],
#         [ 0.01752121,  0.02925109, -0.02762285,  0.03814505,
#           0.03597647, -0.0364292 ,  0.04771555,  0.00339765,
#           0.02951619,  0.00691339],
#         [-0.02897176, -0.0300827 , -0.04947052,  0.03212515,
#           0.00135672, -0.0203939 , -0.00619284,  0.02111692,
#           0.03216496, -0.03797439],
#         [ 0.03451437, -0.01192367, -0.00078678,  0.03459558,
#           0.01035656, -0.00280773, -0.01398744, -0.0201607 ,
#           0.00999612, -0.03423542]],
#
#        [[ 0.0285976 ,  0.04631207, -0.00358213, -0.0376596 ,
#          -0.04114353,  0.03049013,  0.02673307,  0.03592468,
#           0.00895162,  0.04234786],
#         [ 0.0285976 ,  0.04631207, -0.00358213, -0.0376596 ,
#          -0.04114353,  0.03049013,  0.02673307,  0.03592468,
#           0.00895162,  0.04234786],
#         [ 0.0285976 ,  0.04631207, -0.00358213, -0.0376596 ,
#          -0.04114353,  0.03049013,  0.02673307,  0.03592468,
#           0.00895162,  0.04234786],
#         [ 0.0285976 ,  0.04631207, -0.00358213, -0.0376596 ,
#          -0.04114353,  0.03049013,  0.02673307,  0.03592468,
#           0.00895162,  0.04234786],
#         [-0.02006943, -0.00349691,  0.00442221, -0.03003154,
#           0.02992251, -0.03030045, -0.03131988, -0.0471345 ,
#           0.00884849, -0.04877849],
#         [ 0.02397327, -0.01540102, -0.02665034,  0.02836246,
#          -0.04698311,  0.04666511,  0.01879743,  0.03378968,
#          -0.047588  , -0.00058262],
#         [-0.02897176, -0.0300827 , -0.04947052,  0.03212515,
#           0.00135672, -0.0203939 , -0.00619284,  0.02111692,
#           0.03216496, -0.03797439],
#         [ 0.02048932, -0.00081091, -0.02074487, -0.0490299 ,
#           0.02743316,  0.03056253, -0.01264857,  0.03999305,
#          -0.0054839 ,  0.02146466]],
#
#        [[ 0.0285976 ,  0.04631207, -0.00358213, -0.0376596 ,
#          -0.04114353,  0.03049013,  0.02673307,  0.03592468,
#           0.00895162,  0.04234786],
#         [ 0.0285976 ,  0.04631207, -0.00358213, -0.0376596 ,
#          -0.04114353,  0.03049013,  0.02673307,  0.03592468,
#           0.00895162,  0.04234786],
#         [ 0.0285976 ,  0.04631207, -0.00358213, -0.0376596 ,
#          -0.04114353,  0.03049013,  0.02673307,  0.03592468,
#           0.00895162,  0.04234786],
#         [-0.03186357, -0.03665401, -0.04360708, -0.01027089,
#           0.04808302,  0.03034923,  0.03063167,  0.01860226,
#          -0.02280915, -0.0092504 ],
#         [-0.02706718,  0.01649702, -0.01570494,  0.03530476,
#          -0.03792074, -0.0188219 ,  0.03899108, -0.02472034,
#          -0.01986144, -0.0173287 ],
#         [ 0.00759361,  0.04337734,  0.01938269, -0.00912442,
#          -0.01320211, -0.02155881, -0.01178191,  0.02668328,
#          -0.0087713 ,  0.00353686],
#         [ 0.02120502,  0.01789907, -0.00120867,  0.03723357,
#           0.0299066 ,  0.02111221,  0.0197067 ,  0.01259181,
#          -0.00778711,  0.0243223 ],
#         [-0.0151277 , -0.01144912,  0.01282375, -0.01090575,
#          -0.00166797,  0.01663944, -0.04149742, -0.02714441,
#           0.02162397,  0.03232659]],
#
#        [[ 0.0285976 ,  0.04631207, -0.00358213, -0.0376596 ,
#          -0.04114353,  0.03049013,  0.02673307,  0.03592468,
#           0.00895162,  0.04234786],
#         [ 0.0285976 ,  0.04631207, -0.00358213, -0.0376596 ,
#          -0.04114353,  0.03049013,  0.02673307,  0.03592468,
#           0.00895162,  0.04234786],
#         [ 0.0285976 ,  0.04631207, -0.00358213, -0.0376596 ,
#          -0.04114353,  0.03049013,  0.02673307,  0.03592468,
#           0.00895162,  0.04234786],
#         [-0.03186357, -0.03665401, -0.04360708, -0.01027089,
#           0.04808302,  0.03034923,  0.03063167,  0.01860226,
#          -0.02280915, -0.0092504 ],
#         [-0.02706718,  0.01649702, -0.01570494,  0.03530476,
#          -0.03792074, -0.0188219 ,  0.03899108, -0.02472034,
#          -0.01986144, -0.0173287 ],
#         [ 0.00759361,  0.04337734,  0.01938269, -0.00912442,
#          -0.01320211, -0.02155881, -0.01178191,  0.02668328,
#          -0.0087713 ,  0.00353686],
#         [ 0.02120502,  0.01789907, -0.00120867,  0.03723357,
#           0.0299066 ,  0.02111221,  0.0197067 ,  0.01259181,
#          -0.00778711,  0.0243223 ],
#         [ 0.01645592, -0.04584479,  0.0464786 ,  0.00426048,
#          -0.01762792,  0.04359472,  0.04913063, -0.03407251,
#           0.01640508,  0.02509126]],
#
#        [[ 0.0285976 ,  0.04631207, -0.00358213, -0.0376596 ,
#          -0.04114353,  0.03049013,  0.02673307,  0.03592468,
#           0.00895162,  0.04234786],
#         [ 0.0285976 ,  0.04631207, -0.00358213, -0.0376596 ,
#          -0.04114353,  0.03049013,  0.02673307,  0.03592468,
#           0.00895162,  0.04234786],
#         [ 0.0285976 ,  0.04631207, -0.00358213, -0.0376596 ,
#          -0.04114353,  0.03049013,  0.02673307,  0.03592468,
#           0.00895162,  0.04234786],
#         [-0.01036625,  0.03617779,  0.00424295,  0.02394283,
#           0.01675269,  0.04088476,  0.00981764,  0.00807958,
#          -0.03382375, -0.02013717],
#         [-0.02006943, -0.00349691,  0.00442221, -0.03003154,
#           0.02992251, -0.03030045, -0.03131988, -0.0471345 ,
#           0.00884849, -0.04877849],
#         [-0.00891044, -0.01140644, -0.02606823,  0.00333412,
#          -0.00838752, -0.01329622, -0.01735021, -0.01860059,
#           0.0359558 , -0.02671152],
#         [-0.02897176, -0.0300827 , -0.04947052,  0.03212515,
#           0.00135672, -0.0203939 , -0.00619284,  0.02111692,
#           0.03216496, -0.03797439],
#         [-0.03841596,  0.02371545, -0.01978104,  0.03702838,
#           0.02354381, -0.04129971, -0.0378068 ,  0.01224158,
#          -0.04838223, -0.00653747]],
#
#        [[ 0.0285976 ,  0.04631207, -0.00358213, -0.0376596 ,
#          -0.04114353,  0.03049013,  0.02673307,  0.03592468,
#           0.00895162,  0.04234786],
#         [ 0.0285976 ,  0.04631207, -0.00358213, -0.0376596 ,
#          -0.04114353,  0.03049013,  0.02673307,  0.03592468,
#           0.00895162,  0.04234786],
#         [ 0.0285976 ,  0.04631207, -0.00358213, -0.0376596 ,
#          -0.04114353,  0.03049013,  0.02673307,  0.03592468,
#           0.00895162,  0.04234786],
#         [ 0.0285976 ,  0.04631207, -0.00358213, -0.0376596 ,
#          -0.04114353,  0.03049013,  0.02673307,  0.03592468,
#           0.00895162,  0.04234786],
#         [ 0.02651301, -0.03013676, -0.03658489,  0.0240812 ,
#           0.04780931, -0.03246312,  0.01506449,  0.01905164,
#          -0.00694071, -0.0424469 ],
#         [ 0.00636687, -0.02951111, -0.03204706,  0.00443233,
#           0.02185861, -0.03067526,  0.03717684,  0.01622725,
#          -0.03036298,  0.03115829],
#         [-0.00137855,  0.04519187,  0.01043072, -0.01958655,
#           0.03072733,  0.04725185, -0.04659147, -0.02831832,
#          -0.00578271, -0.04197515],
#         [ 0.02120502,  0.01789907, -0.00120867,  0.03723357,
#           0.0299066 ,  0.02111221,  0.0197067 ,  0.01259181,
#          -0.00778711,  0.0243223 ]]], dtype=float32)

# %%
model.predict(embedded_docs[0:1])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# array([[[ 0.0494617 ,  0.03726963, -0.00629456,  0.04380733,
#          -0.02562037, -0.01139917, -0.01726042,  0.02793333,
#          -0.01439047, -0.02995409],
#         [ 0.0494617 ,  0.03726963, -0.00629456,  0.04380733,
#          -0.02562037, -0.01139917, -0.01726042,  0.02793333,
#          -0.01439047, -0.02995409],
#         [ 0.0494617 ,  0.03726963, -0.00629456,  0.04380733,
#          -0.02562037, -0.01139917, -0.01726042,  0.02793333,
#          -0.01439047, -0.02995409],
#         [ 0.0494617 ,  0.03726963, -0.00629456,  0.04380733,
#          -0.02562037, -0.01139917, -0.01726042,  0.02793333,
#          -0.01439047, -0.02995409],
#         [-0.00085939, -0.02729224, -0.0198691 , -0.01669455,
#          -0.0146367 ,  0.0143206 , -0.03033089,  0.0459406 ,
#          -0.00780817, -0.01599345],
#         [-0.02456909,  0.0174212 , -0.01624648, -0.04767518,
#           0.00155668,  0.02080565, -0.02892951, -0.04325992,
#          -0.01605765, -0.0044387 ],
#         [ 0.03969437,  0.03603978, -0.01629563, -0.02539505,
#          -0.01649944, -0.02598451, -0.00261507,  0.03785786,
#           0.0238277 ,  0.02515868],
#         [-0.03129192,  0.01216315, -0.02668122,  0.01483079,
#          -0.03598962, -0.00910785, -0.00257253,  0.0205929 ,
#           0.02170143, -0.02434467]]], dtype=float32)
